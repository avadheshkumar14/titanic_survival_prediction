# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test  = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.drop(["Cabin"], axis = 1, inplace = True)
test.drop(["Cabin"], axis = 1, inplace = True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=train)

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29

        else:
            return 24

    else:
        return Age

# %%
train['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)
test['Age'] = train[['Age','Pclass']].apply(impute_age,axis=1)

# %%
corr_matrix = train.corr()

# %%
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.047255
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sns.boxplot(x=train['Fare'])

# %%
sns.boxplot(x=train['PassengerId'])

# %%
sns.boxplot(x=train['Age'])

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('SibSp')

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %%
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Embarked
# 0          892       3    male  22.0      0      0   330911   7.8292        Q
# 1          893       3  female  38.0      1      0   363272   7.0000        S
# 2          894       2    male  26.0      0      0   240276   9.6875        Q
# 3          895       3    male  35.0      0      0   315154   8.6625        S
# 4          896       3  female  35.0      1      1  3101298  12.2875        S

# %%
train_test_data = [train, test] # combining train and test dataset

# %%
train_test_data
# Out:
# [     PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
#  0              1         0       3    male  22.0      1      0
#  1              2         1       1  female  38.0      1      0
#  2              3         1       3  female  26.0      0      0
#  3              4         1       1  female  35.0      1      0
#  4              5         0       3    male  35.0      0      0
#  5              6         0       3    male  24.0      0      0
#  6              7         0       1    male  54.0      0      0
#  7              8         0       3    male   2.0      3      1
#  8              9         1       3  female  27.0      0      2
#  9             10         1       2  female  14.0      1      0
#  10            11         1       3  female   4.0      1      1
#  11            12         1       1  female  58.0      0      0
#  12            13         0       3    male  20.0      0      0
#  13            14         0       3    male  39.0      1      5
#  14            15         0       3  female  14.0      0      0
#  15            16         1       2  female  55.0      0      0
#  16            17         0       3    male   2.0      4      1
#  17            18         1       2    male  29.0      0      0
#  18            19         0       3  female  31.0      1      0
#  19            20         1       3  female  24.0      0      0
#  20            21         0       2    male  35.0      0      0
#  21            22         1       2    male  34.0      0      0
#  22            23         1       3  female  15.0      0      0
#  23            24         1       1    male  28.0      0      0
#  24            25         0       3  female   8.0      3      1
#  25            26         1       3  female  38.0      1      5
#  26            27         0       3    male  24.0      0      0
#  27            28         0       1    male  19.0      3      2
#  28            29         1       3  female  24.0      0      0
#  29            30         0       3    male  24.0      0      0
#  ..           ...       ...     ...     ...   ...    ...    ...
#  861          862         0       2    male  21.0      1      0
#  862          863         1       1  female  48.0      0      0
#  863          864         0       3  female  24.0      8      2
#  864          865         0       2    male  24.0      0      0
#  865          866         1       2  female  42.0      0      0
#  866          867         1       2  female  27.0      1      0
#  867          868         0       1    male  31.0      0      0
#  868          869         0       3    male  24.0      0      0
#  869          870         1       3    male   4.0      1      1
#  870          871         0       3    male  26.0      0      0
#  871          872         1       1  female  47.0      1      1
#  872          873         0       1    male  33.0      0      0
#  873          874         0       3    male  47.0      0      0
#  874          875         1       2  female  28.0      1      0
#  875          876         1       3  female  15.0      0      0
#  876          877         0       3    male  20.0      0      0
#  877          878         0       3    male  19.0      0      0
#  878          879         0       3    male  24.0      0      0
#  879          880         1       1  female  56.0      0      1
#  880          881         1       2  female  25.0      0      1
#  881          882         0       3    male  33.0      0      0
#  882          883         0       3  female  22.0      0      0
#  883          884         0       2    male  28.0      0      0
#  884          885         0       3    male  25.0      0      0
#  885          886         0       3  female  39.0      0      5
#  886          887         0       2    male  27.0      0      0
#  887          888         1       1  female  19.0      0      0
#  888          889         0       3  female  24.0      1      2
#  889          890         1       1    male  26.0      0      0
#  890          891         0       3    male  32.0      0      0
#
#                 Ticket      Fare Embarked
#  0           A/5 21171    7.2500        S
#  1            PC 17599   71.2833        C
#  2    STON/O2. 3101282    7.9250        S
#  3              113803   53.1000        S
#  4              373450    8.0500        S
#  5              330877    8.4583        Q
#  6               17463   51.8625        S
#  7              349909   21.0750        S
#  8              347742   11.1333        S
#  9              237736   30.0708        C
#  10            PP 9549   16.7000        S
#  11             113783   26.5500        S
#  12          A/5. 2151    8.0500        S
#  13             347082   31.2750        S
#  14             350406    7.8542        S
#  15             248706   16.0000        S
#  16             382652   29.1250        Q
#  17             244373   13.0000        S
#  18             345763   18.0000        S
#  19               2649    7.2250        C
#  20             239865   26.0000        S
#  21             248698   13.0000        S
#  22             330923    8.0292        Q
#  23             113788   35.5000        S
#  24             349909   21.0750        S
#  25             347077   31.3875        S
#  26               2631    7.2250        C
#  27              19950  263.0000        S
#  28             330959    7.8792        Q
#  29             349216    7.8958        S
#  ..                ...       ...      ...
#  861             28134   11.5000        S
#  862             17466   25.9292        S
#  863          CA. 2343   69.5500        S
#  864            233866   13.0000        S
#  865            236852   13.0000        S
#  866     SC/PARIS 2149   13.8583        C
#  867          PC 17590   50.4958        S
#  868            345777    9.5000        S
#  869            347742   11.1333        S
#  870            349248    7.8958        S
#  871             11751   52.5542        S
#  872               695    5.0000        S
#  873            345765    9.0000        S
#  874         P/PP 3381   24.0000        C
#  875              2667    7.2250        C
#  876              7534    9.8458        S
#  877            349212    7.8958        S
#  878            349217    7.8958        S
#  879             11767   83.1583        C
#  880            230433   26.0000        S
#  881            349257    7.8958        S
#  882              7552   10.5167        S
#  883  C.A./SOTON 34068   10.5000        S
#  884   SOTON/OQ 392076    7.0500        S
#  885            382652   29.1250        Q
#  886            211536   13.0000        S
#  887            112053   30.0000        S
#  888        W./C. 6607   23.4500        S
#  889            111369   30.0000        C
#  890            370376    7.7500        Q
#
#  [891 rows x 10 columns],
#       PassengerId  Pclass     Sex   Age  SibSp  Parch              Ticket  \
#  0            892       3    male  22.0      0      0              330911
#  1            893       3  female  38.0      1      0              363272
#  2            894       2    male  26.0      0      0              240276
#  3            895       3    male  35.0      0      0              315154
#  4            896       3  female  35.0      1      1             3101298
#  5            897       3    male  24.0      0      0                7538
#  6            898       3  female  54.0      0      0              330972
#  7            899       2    male   2.0      1      1              248738
#  8            900       3  female  27.0      0      0                2657
#  9            901       3    male  14.0      2      0           A/4 48871
#  10           902       3    male   4.0      0      0              349220
#  11           903       1    male  58.0      0      0                 694
#  12           904       1  female  20.0      1      0               21228
#  13           905       2    male  39.0      1      0               24065
#  14           906       1  female  14.0      1      0         W.E.P. 5734
#  15           907       2  female  55.0      1      0       SC/PARIS 2167
#  16           908       2    male   2.0      0      0              233734
#  17           909       3    male  29.0      0      0                2692
#  18           910       3  female  31.0      1      0    STON/O2. 3101270
#  19           911       3  female  24.0      0      0                2696
#  20           912       1    male  35.0      1      0            PC 17603
#  21           913       3    male  34.0      0      1             C 17368
#  22           914       1  female  15.0      0      0            PC 17598
#  23           915       1    male  28.0      0      1            PC 17597
#  24           916       1  female   8.0      1      3            PC 17608
#  25           917       3    male  38.0      1      0           A/5. 3337
#  26           918       1  female  24.0      0      1              113509
#  27           919       3    male  19.0      0      0                2698
#  28           920       1    male  24.0      0      0              113054
#  29           921       3    male  24.0      2      0                2662
#  ..           ...     ...     ...   ...    ...    ...                 ...
#  388         1280       3    male  24.0      0      0              364858
#  389         1281       3    male  17.0      3      1              349909
#  390         1282       1    male  36.0      0      0               12749
#  391         1283       1  female  21.0      0      1            PC 17592
#  392         1284       3    male  28.0      0      2           C.A. 2673
#  393         1285       2    male  23.0      0      0          C.A. 30769
#  394         1286       3    male  24.0      3      1              315153
#  395         1287       1  female  22.0      1      0               13695
#  396         1288       3    male  31.0      0      0              371109
#  397         1289       1  female  46.0      1      1               13567
#  398         1290       3    male  23.0      0      0              347065
#  399         1291       3    male  28.0      0      0               21332
#  400         1292       1  female  39.0      0      0               36928
#  401         1293       2    male  26.0      1      0               28664
#  402         1294       1  female  21.0      0      1              112378
#  403         1295       1    male  28.0      0      0              113059
#  404         1296       1    male  20.0      1      0               17765
#  405         1297       2    male  34.0      0      0       SC/PARIS 2166
#  406         1298       2    male  51.0      1      0               28666
#  407         1299       1    male   3.0      1      1              113503
#  408         1300       3  female  21.0      0      0              334915
#  409         1301       3  female  24.0      1      1  SOTON/O.Q. 3101315
#  410         1302       3  female  24.0      0      0              365237
#  411         1303       1  female  24.0      1      0               19928
#  412         1304       3  female  33.0      0      0              347086
#  413         1305       3    male  29.0      0      0           A.5. 3236
#  414         1306       1  female  44.0      0      0            PC 17758
#  415         1307       3    male  24.0      0      0  SOTON/O.Q. 3101262
#  416         1308       3    male  34.0      0      0              359309
#  417         1309       3    male  18.0      1      1                2668
#
#           Fare Embarked
#  0      7.8292        Q
#  1      7.0000        S
#  2      9.6875        Q
#  3      8.6625        S
#  4     12.2875        S
#  5      9.2250        S
#  6      7.6292        Q
#  7     29.0000        S
#  8      7.2292        C
#  9     24.1500        S
#  10     7.8958        S
#  11    26.0000        S
#  12    82.2667        S
#  13    26.0000        S
#  14    61.1750        S
#  15    27.7208        C
#  16    12.3500        Q
#  17     7.2250        C
#  18     7.9250        S
#  19     7.2250        C
#  20    59.4000        C
#  21     3.1708        S
#  22    31.6833        S
#  23    61.3792        C
#  24   262.3750        C
#  25    14.5000        S
#  26    61.9792        C
#  27     7.2250        C
#  28    30.5000        S
#  29    21.6792        C
#  ..        ...      ...
#  388    7.7500        Q
#  389   21.0750        S
#  390   93.5000        S
#  391   39.4000        S
#  392   20.2500        S
#  393   10.5000        S
#  394   22.0250        S
#  395   60.0000        S
#  396    7.2500        Q
#  397   79.2000        C
#  398    7.7750        S
#  399    7.7333        Q
#  400  164.8667        S
#  401   21.0000        S
#  402   59.4000        C
#  403   47.1000        S
#  404   27.7208        C
#  405   13.8625        C
#  406   10.5000        S
#  407  211.5000        C
#  408    7.7208        Q
#  409   13.7750        S
#  410    7.7500        Q
#  411   90.0000        Q
#  412    7.7750        S
#  413    8.0500        S
#  414  108.9000        C
#  415    7.2500        S
#  416    8.0500        S
#  417   22.3583        C
#
#  [418 rows x 9 columns]]

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  22.0      1      0         A/5 21171
# 1            2         1       1    1  38.0      1      0          PC 17599
# 2            3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  35.0      1      0            113803
# 4            5         0       3    0  35.0      0      0            373450
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3,
    dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')

# %%
embarked_mapping = {"S": 0, "C": 1, "Q": 2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %%
train.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train["Fare"].fillna(train.groupby("Pclass")["Fare"].transform("median"), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  3.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  1.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  2.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# 11           12         1       1    1  3.0      0      0            113783
# 12           13         0       3    0  1.0      0      0         A/5. 2151
# 13           14         0       3    0  3.0      1      5            347082
# 14           15         0       3    1  0.0      0      0            350406
# 15           16         1       2    1  3.0      0      0            248706
# 16           17         0       3    0  0.0      4      1            382652
# 17           18         1       2    0  2.0      0      0            244373
# 18           19         0       3    1  2.0      1      0            345763
# 19           20         1       3    1  1.0      0      0              2649
# 20           21         0       2    0  2.0      0      0            239865
# 21           22         1       2    0  2.0      0      0            248698
# 22           23         1       3    1  0.0      0      0            330923
# 23           24         1       1    0  2.0      0      0            113788
# 24           25         0       3    1  0.0      3      1            349909
# 25           26         1       3    1  3.0      1      5            347077
# 26           27         0       3    0  1.0      0      0              2631
# 27           28         0       1    0  1.0      3      2             19950
# 28           29         1       3    1  1.0      0      0            330959
# 29           30         0       3    0  1.0      0      0            349216
# 30           31         0       1    0  3.0      0      0          PC 17601
# 31           32         1       1    1  3.0      1      0          PC 17569
# 32           33         1       3    1  1.0      0      0            335677
# 33           34         0       2    0  4.0      0      0        C.A. 24579
# 34           35         0       1    0  2.0      1      0          PC 17604
# 35           36         0       1    0  3.0      1      0            113789
# 36           37         1       3    0  1.0      0      0              2677
# 37           38         0       3    0  1.0      0      0        A./5. 2152
# 38           39         0       3    1  1.0      2      0            345764
# 39           40         1       3    1  0.0      1      0              2651
# 40           41         0       3    1  3.0      1      0              7546
# 41           42         0       2    1  2.0      1      0             11668
# 42           43         0       3    0  1.0      0      0            349253
# 43           44         1       2    1  0.0      1      2     SC/Paris 2123
# 44           45         1       3    1  1.0      0      0            330958
# 45           46         0       3    0  1.0      0      0   S.C./A.4. 23567
# 46           47         0       3    0  1.0      1      0            370371
# 47           48         1       3    1  1.0      0      0             14311
# 48           49         0       3    0  1.0      2      0              2662
# 49           50         0       3    1  1.0      1      0            349237
#
#         Fare  Embarked
# 0     7.2500         0
# 1    71.2833         1
# 2     7.9250         0
# 3    53.1000         0
# 4     8.0500         0
# 5     8.4583         2
# 6    51.8625         0
# 7    21.0750         0
# 8    11.1333         0
# 9    30.0708         1
# 10   16.7000         0
# 11   26.5500         0
# 12    8.0500         0
# 13   31.2750         0
# 14    7.8542         0
# 15   16.0000         0
# 16   29.1250         2
# 17   13.0000         0
# 18   18.0000         0
# 19    7.2250         1
# 20   26.0000         0
# 21   13.0000         0
# 22    8.0292         2
# 23   35.5000         0
# 24   21.0750         0
# 25   31.3875         0
# 26    7.2250         1
# 27  263.0000         0
# 28    7.8792         2
# 29    7.8958         0
# 30   27.7208         1
# 31  146.5208         1
# 32    7.7500         2
# 33   10.5000         0
# 34   82.1708         1
# 35   52.0000         0
# 36    7.2292         1
# 37    8.0500         0
# 38   18.0000         0
# 39   11.2417         1
# 40    9.4750         0
# 41   21.0000         0
# 42    7.8958         1
# 43   41.5792         1
# 44    7.8792         2
# 45    8.0500         0
# 46   15.5000         2
# 47    7.7500         2
# 48   21.6792         1
# 49   17.8000         0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Embarked       891 non-null int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 69.7+ KB

# %%
features_drop = ['Ticket', 'SibSp', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

# %%
train_data
# Out:
#      Pclass  Sex  Age      Fare  Embarked
# 0         3    0  1.0    7.2500         0
# 1         1    1  3.0   71.2833         1
# 2         3    1  1.0    7.9250         0
# 3         1    1  2.0   53.1000         0
# 4         3    0  2.0    8.0500         0
# 5         3    0  1.0    8.4583         2
# 6         1    0  3.0   51.8625         0
# 7         3    0  0.0   21.0750         0
# 8         3    1  2.0   11.1333         0
# 9         2    1  0.0   30.0708         1
# 10        3    1  0.0   16.7000         0
# 11        1    1  3.0   26.5500         0
# 12        3    0  1.0    8.0500         0
# 13        3    0  3.0   31.2750         0
# 14        3    1  0.0    7.8542         0
# 15        2    1  3.0   16.0000         0
# 16        3    0  0.0   29.1250         2
# 17        2    0  2.0   13.0000         0
# 18        3    1  2.0   18.0000         0
# 19        3    1  1.0    7.2250         1
# 20        2    0  2.0   26.0000         0
# 21        2    0  2.0   13.0000         0
# 22        3    1  0.0    8.0292         2
# 23        1    0  2.0   35.5000         0
# 24        3    1  0.0   21.0750         0
# 25        3    1  3.0   31.3875         0
# 26        3    0  1.0    7.2250         1
# 27        1    0  1.0  263.0000         0
# 28        3    1  1.0    7.8792         2
# 29        3    0  1.0    7.8958         0
# ..      ...  ...  ...       ...       ...
# 861       2    0  1.0   11.5000         0
# 862       1    1  3.0   25.9292         0
# 863       3    1  1.0   69.5500         0
# 864       2    0  1.0   13.0000         0
# 865       2    1  3.0   13.0000         0
# 866       2    1  2.0   13.8583         1
# 867       1    0  2.0   50.4958         0
# 868       3    0  1.0    9.5000         0
# 869       3    0  0.0   11.1333         0
# 870       3    0  1.0    7.8958         0
# 871       1    1  3.0   52.5542         0
# 872       1    0  2.0    5.0000         0
# 873       3    0  3.0    9.0000         0
# 874       2    1  2.0   24.0000         1
# 875       3    1  0.0    7.2250         1
# 876       3    0  1.0    9.8458         0
# 877       3    0  1.0    7.8958         0
# 878       3    0  1.0    7.8958         0
# 879       1    1  3.0   83.1583         1
# 880       2    1  1.0   26.0000         0
# 881       3    0  2.0    7.8958         0
# 882       3    1  1.0   10.5167         0
# 883       2    0  2.0   10.5000         0
# 884       3    0  1.0    7.0500         0
# 885       3    1  3.0   29.1250         2
# 886       2    0  2.0   13.0000         0
# 887       1    1  1.0   30.0000         0
# 888       3    1  1.0   23.4500         0
# 889       1    0  1.0   30.0000         1
# 890       3    0  2.0    7.7500         2
#
# [891 rows x 5 columns]

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.73333333 0.78651685 0.69662921 0.64044944 0.73033708 0.71910112
#  0.79775281 0.7752809  0.76404494 0.70786517]

# %%
round(np.mean(score)*100, 2)
# Out:
# 73.51

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.74444444 0.85393258 0.83146067 0.74157303 0.79775281 0.82022472
#  0.7752809  0.80898876 0.71910112 0.85393258]

# %%
round(np.mean(score)*100, 2)
# Out:
# 79.47

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.74444444 0.85393258 0.78651685 0.7752809  0.80898876 0.79775281
#  0.7752809  0.78651685 0.73033708 0.82022472]

# %%
round(np.mean(score)*100, 2)
# Out:
# 78.79

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.78888889 0.78651685 0.76404494 0.74157303 0.75280899 0.78651685
#  0.78651685 0.78651685 0.7752809  0.79775281]

# %%
round(np.mean(score)*100, 2)
# Out:
# 77.66

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\avadh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [0.77777778 0.76404494 0.75280899 0.71910112 0.76404494 0.79775281
#  0.82022472 0.78651685 0.73033708 0.7752809 ]

# %%
round(np.mean(score)*100, 2)
# Out:
# 76.88

# %%
clf = RandomForestClassifier(n_estimators=13)
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
submission = pd.read_csv('submission.csv')
submission.head(420)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         1
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         1
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         1
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         0
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         1
# 406         1298         1
# 407         1299         1
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission = pd.read_csv('submission.csv')
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# dtypes: int64(2)
# memory usage: 6.6 KB

# %%
customer_data_copy = data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f341161bfe5f> in <module>
# ----> 1 customer_data_copy = data.copy()
#
# NameError: name 'data' is not defined
